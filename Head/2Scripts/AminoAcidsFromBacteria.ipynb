# %%
import pandas as pd

# %%
import Bio as bio
from Bio import SeqIO

# %%
d = pd.Series(index=range(1,1001))
bac = pd.DataFrame(d)
# Out:
# <ipython-input-121-8ca214e69e8a>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   d = pd.Series(index=range(1,1001))

# %%
bac.head()
# Out:
#     0
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN

# %%
bac.loc[0:100, 'HumanGeneAnalog'] = 'ATP6'

# %%
bac.loc[0:100, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ATP6.txt", "fasta")]

# %%
AA = list('ARNDCQEGHILKMFPSTWYV')

# %%
for i in AA:
    bac[i] = 0

# %%
for a in AA:
    bac.loc[0:100, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ATP6.txt", "fasta")]

# %%
bac.loc[101:200, 'HumanGeneAnalog'] = 'COX1'
bac.loc[101:200, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX1.txt", "fasta")]
for a in AA:
    bac.loc[101:200, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX1.txt", "fasta")]

# %%
bac.loc[201:300, 'HumanGeneAnalog'] = 'COX2'
bac.loc[201:300, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX2.txt", "fasta")]
for a in AA:
    bac.loc[201:300, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX2.txt", "fasta")]

# %%
bac.loc[301:400, 'HumanGeneAnalog'] = 'COX3'
bac.loc[301:400, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX3.txt", "fasta")]
for a in AA:
    bac.loc[301:400, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\COX3.txt", "fasta")]

# %%
bac.loc[401:500, 'HumanGeneAnalog'] = 'CYTB'
bac.loc[401:500, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\CYTB.txt", "fasta")]
for a in AA:
    bac.loc[401:500, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\CYTB.txt", "fasta")]

# %%
bac.loc[501:600, 'HumanGeneAnalog'] = 'ND1'
bac.loc[501:600, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND1.txt", "fasta")]
for a in AA:
    bac.loc[501:600, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND1.txt", "fasta")]

# %%
bac.loc[601:700, 'HumanGeneAnalog'] = 'ND2'
bac.loc[601:700, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND2.txt", "fasta")]
for a in AA:
    bac.loc[601:700, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND2.txt", "fasta")]

# %%
bac.loc[701:800, 'HumanGeneAnalog'] = 'ND3'
bac.loc[701:800, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND3.txt", "fasta")]
for a in AA:
    bac.loc[701:800, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND3.txt", "fasta")]

# %%
bac.loc[801:900, 'HumanGeneAnalog'] = 'ND4'
bac.loc[801:900, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND4.txt", "fasta")]
for a in AA:
    bac.loc[801:900, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND4.txt", "fasta")]

# %%
bac.loc[901:1000, 'HumanGeneAnalog'] = 'ND5'
bac.loc[901:1000, 'GeneName'] = [seq_record.description.split(maxsplit=1)[1] for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND5.txt", "fasta")]
for a in AA:
    bac.loc[901:1000, a] = [seq_record.seq.count(a) for seq_record in SeqIO.parse(r"C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\ND5.txt", "fasta")]

# %%
bac
# Out:
#      HumanGeneAnalog                                           GeneName  Ala  \
# 1               ATP6  MULTISPECIES: F0F1 ATP synthase subunit A [Pro...   11
# 2               ATP6  F0F1 ATP synthase subunit A [Bradyrhizobium ca...   15
# 3               ATP6  F0F1 ATP synthase subunit A [Bradyrhizobium ca...   16
# 4               ATP6  F0F1 ATP synthase subunit A, partial [Bradyrhi...   15
# 5               ATP6  F0F1 ATP synthase subunit A [Sandarakinorhabdu...   22
# ...              ...                                                ...  ...
# 996              ND5  NADH-quinone oxidoreductase subunit L [Rhodosp...   54
# 997              ND5  NADH-quinone oxidoreductase subunit L [Candida...   38
# 998              ND5  NADH-quinone oxidoreductase subunit L [Crenalk...   60
# 999              ND5  NADH:ubiquinone oxidoreductase subunit L [Stel...   59
# 1000             ND5  NADH-quinone oxidoreductase subunit L [Rhodosp...   52
#
# ...

# %%
bac.drop([0], axis='columns', inplace=True)
bac.columns = ['HumanGeneAnalog','GeneName','Ala','Arg','Asn','Asp','Cys','Gln','Glu','Gly','His','Ile','Leu','Lys','Met','Phe','Pro','Ser','Thr','Trp','Tyr','Val']

# %%
bac.to_csv(r'C:\Users\aaren\OneDrive\Рабочий стол\bac_genes\AminoAcidsFromBacteria.csv', sep=';')
